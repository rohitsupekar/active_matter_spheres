# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.pcolormesh(np.random.rand(100,100), cmap='RdBu_r')
clb = plt.colorbar(); plt.clim([0, 1])
clb.set_ticks([0, 0.5, 1])
plt.savefig("colbar.pdf")

# %%
# Out:
# array([[0.38704904, 0.51359549],
#        [0.0608735 , 0.28008504]])
